# %%
import numpy as np #
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np #
#       2 import pandas as pd
# ----> 3 import seaborn as sns
#       4 import matplotlib.pyplot as plt
#       5 import warnings
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
df = pd.read_csv("/content/Herpes_Outbreak.csv")

# %%
df.head()
# Out:
#    Age  Gender  Years_Since_Diagnosis  Outbreak_Flag  Severity  Stress_Level  \
# 0   52  Female                     14              0         1             5
# 1   21    Male                     29              1         7             6
# 2   29    Male                     29              1         7             6
# 3   53    Male                      1              0         8             8
# 4   22  Female                     14              0        10            10
#
#    Fatigue_Level  Illness_Flag  Medication_Flag  Temperature  Sleep_Hours  \
# 0              5             0                1         37.8          0.4
# 1              5             1                1         38.1          2.1
# 2              5             1                1         38.1          2.1
# 3              5             1                0         36.0          3.4
# 4              5             0                1         36.1          2.3
#
#    Days_Since_Last_Outbreak  Next_Outbreak_Days
# ...

# %%
df.tail()
# Out:
#       Age  Gender  Years_Since_Diagnosis  Outbreak_Flag  Severity  \
# 2995   49  Female                      8              0         5
# 2996   43    Male                     17              1         2
# 2997   36  Female                     15              0         4
# 2998   24  Female                     15              0         4
# 2999   37    Male                     19              0         5
#
#       Stress_Level  Fatigue_Level  Illness_Flag  Medication_Flag  Temperature  \
# 2995             5              2             1                1         42.9
# 2996             8              3             0                1         36.4
# 2997             9             10             0                1         39.1
# 2998             9             10             0                1         39.1
# 2999             9              2             0                1         37.8
#
#       Sleep_Hours  Days_Since_Last_Outbreak  Next_Outbreak_Days
# ...

# %%
df.describe()
# Out:
#                Age  Years_Since_Diagnosis  Outbreak_Flag     Severity  \
# count  3000.000000            3000.000000    3000.000000  3000.000000
# mean     43.335667              13.841333       0.332667     5.415000
# std      14.402227               6.444584       0.471247     2.844317
# min      18.000000               1.000000       0.000000     1.000000
# 25%      32.000000              11.000000       0.000000     2.000000
# 50%      42.000000              14.000000       0.000000     5.000000
# 75%      52.000000              16.250000       1.000000     7.250000
# max      99.000000              37.000000       1.000000    10.000000
#
#        Stress_Level  Fatigue_Level  Illness_Flag  Medication_Flag  \
# count   3000.000000    3000.000000   3000.000000      3000.000000
# mean       6.919000       4.001333      0.416000         0.750667
# std        2.362407       2.201881      0.492976         0.432699
# min        2.000000       1.000000      0.000000         0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       3000 non-null   int64
#  1   Gender                    3000 non-null   object
#  2   Years_Since_Diagnosis     3000 non-null   int64
#  3   Outbreak_Flag             3000 non-null   int64
#  4   Severity                  3000 non-null   int64
#  5   Stress_Level              3000 non-null   int64
#  6   Fatigue_Level             3000 non-null   int64
#  7   Illness_Flag              3000 non-null   int64
#  8   Medication_Flag           3000 non-null   int64
#  9   Temperature               3000 non-null   float64
#  10  Sleep_Hours               3000 non-null   float64
#  11  Days_Since_Last_Outbreak  3000 non-null   int64
#  12  Next_Outbreak_Days        3000 non-null   int64
# dtypes: float64(2), int64(10), object(1)
# ...

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# Age                         0
# Gender                      0
# Years_Since_Diagnosis       0
# Outbreak_Flag               0
# Severity                    0
# Stress_Level                0
# Fatigue_Level               0
# Illness_Flag                0
# Medication_Flag             0
# Temperature                 0
# Sleep_Hours                 0
# Days_Since_Last_Outbreak    0
# Next_Outbreak_Days          0
# dtype: int64

# %%
df.shape
# Out:
# (3000, 13)

# %%
df = df[['Age', 'Gender', 'Years_Since_Diagnosis', 'Outbreak_Flag', 'Severity', 'Stress_Level', 'Fatigue_Level', 'Illness_Flag','Medication_Flag', 'Temperature', 'Sleep_Hours','Days_Since_Last_Outbreak', 'Next_Outbreak_Days']]

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    1503
# Male      1497
# Name: count, dtype: int64

# %%
sns.scatterplot(data=df, x='Stress_Level', y='Fatigue_Level', hue='Severity', palette='cool')
plt.title('Scatter Plot: Fatigue vs. Stress Level')
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.lineplot(data=df, x='Days_Since_Last_Outbreak', y='Temperature', marker='o')
plt.title('Temperature vs. Days Since Last Outbreak')
plt.show()

# %%
sns.countplot(data=df, x='Outbreak_Flag', hue='Gender')
plt.title('Outbreak Frequency by Gender')
plt.show()

# %%
X = df.drop(['Next_Outbreak_Days'], axis=1)
y = df['Next_Outbreak_Days']

# %%
pip install scikeras

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler, FunctionTransformer
from sklearn.pipeline import Pipeline
from scikeras.wrappers import KerasRegressor  # Use scikeras wrapper
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# %%
le = LabelEncoder()
X['Gender'] = le.fit_transform(X['Gender'])
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Reshape for LSTM (samples, timesteps, features)
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# Build the LSTM model
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dense(1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Train the model
history =model.fit(X_train, y_train, epochs=150, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/150
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 42811.6484 - val_loss: 43433.8438
# Epoch 2/150
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 40781.0352 - val_loss: 42690.8555
# Epoch 3/150
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 38394.2695 - val_loss: 41108.0664
# Epoch 4/150
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 38595.6016 - val_loss: 38712.0430
# Epoch 5/150
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 31950.6035 - val_loss: 35680.2383
# Epoch 6/150
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 32884.8125 - val_loss: 32175.3008
# Epoch 7/150
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 30118.2285 - val_loss: 28429.0391
# Epoch 8/150
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 27646.0469 - val_loss: 24793.2070
# Epoch 9/150
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 22109.0039 - val_loss: 21364.7422
# Epoch 10/150
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 20249.9805 - val_loss: 18211.2266
# Epoch 11/150
# ...

# %%
# Plotting the training and validation loss
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# %%
model.save('lstm_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from keras.models import load_model
loaded_model = load_model('lstm_model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
df
# Out:
#       Age  Gender  Years_Since_Diagnosis  Outbreak_Flag  Severity  \
# 0      52  Female                     14              0         1
# 1      21    Male                     29              1         7
# 2      29    Male                     29              1         7
# 3      53    Male                      1              0         8
# 4      22  Female                     14              0        10
# ...   ...     ...                    ...            ...       ...
# 2995   49  Female                      8              0         5
# 2996   43    Male                     17              1         2
# 2997   36  Female                     15              0         4
# 2998   24  Female                     15              0         4
# 2999   37    Male                     19              0         5
#
#       Stress_Level  Fatigue_Level  Illness_Flag  Medication_Flag  Temperature  \
# 0                5              5             0                1         37.8
# ...

# %%
# Assuming you have new input data in the same format as X_test
new_data = np.array([[34, 0, 14,0, 1, 5, 5, 0,1, 37.8, 0.4, 89]])

# 1. Preprocess the new input data
new_data_scaled = scaler.transform(new_data)  # Apply the same scaling used during training
new_data_reshaped = np.reshape(new_data_scaled.astype(np.float32), (new_data_scaled.shape[0], 1, new_data_scaled.shape[1]))

# 2. Use the loaded model to make predictions
predicted_outcome = loaded_model.predict(new_data_reshaped)

# 3. Display the prediction
print(f'Predicted Next Outbreak Days: {predicted_outcome[0][0].round()}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# Predicted Next Outbreak Days: 13.0

# %%
# Assuming you have new input data in the same format as X_test
new_data = np.array([[49, 0, 8, 0, 5, 5, 2, 1, 1, 42.9, 2.6, 320]])

# 1. Preprocess the new input data
new_data_scaled = scaler.transform(new_data)  # Apply the same scaling used during training
new_data_reshaped = np.reshape(new_data_scaled.astype(np.float32), (new_data_scaled.shape[0], 1, new_data_scaled.shape[1]))

# 2. Use the loaded model to make predictions
predicted_outcome = loaded_model.predict(new_data_reshaped)

# 3. Display the prediction
print(f'Predicted Next Outbreak Days: {predicted_outcome[0][0].round()}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted Next Outbreak Days: 86.0
